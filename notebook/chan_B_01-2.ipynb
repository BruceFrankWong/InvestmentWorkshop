# %%
import os
from pathlib import Path

NOTEBOOK_PATH: Path = Path(os.path.abspath(''))

DATA_PATH: Path = NOTEBOOK_PATH.parent.joinpath('data')

PATH_FOR_RESULT: Path = NOTEBOOK_PATH.joinpath('RESULT')

if not PATH_FOR_RESULT.exists():
    PATH_FOR_RESULT.mkdir()

print(f'当前运行目录：{NOTEBOOK_PATH}')
print(f'当前数据目录：{DATA_PATH}')
# Out:
# 当前运行目录：D:\Development\Python\InvestmentWorkshop\notebook
# 当前数据目录：D:\Development\Python\InvestmentWorkshop\data

# %% [markdown]
# # 缠论 B-01-2
#
# 在[缠论 B-01-1](chan_B_01-1.ipynb)的基础上，程序化合并K线。

# %% [markdown]
# ## 准备

# %% [markdown]
# ### 引用模块

# %%
import pandas as pd

from utility import (
    get_available_datafile_name,
    load_csv_as_dataframe,
)
from InvestmentWorkshop.indicator import (
    pbx,
    chan_on_bar_dataframe,
    plot_chan_dataframe
)
# Out:
# Load succeed.

# %% [markdown]
# ### 设置 pandas

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

# %% [markdown]
# ### 可用数据

# %%
available_datafile = get_available_datafile_name(DATA_PATH, 'Minute')
for symbol, period in available_datafile:
    print(f'symbol: {symbol:>12}, period: {period}')
# Out:
# symbol:    DCE.c2201, period: Minute
# symbol:    DCE.i2201, period: Minute
# symbol:  SHFE.ag2106, period: Minute
# symbol:  SHFE.al2111, period: Minute
# symbol:  SHFE.al2112, period: Minute
# symbol:  SHFE.hc2110, period: Minute
# symbol:  SHFE.hc2201, period: Minute
# symbol:  SHFE.hc2202, period: Minute
# symbol:  SHFE.rb2201, period: Minute

# %% [markdown]
# ### 声明数据
#
# 使用分钟数据。

# %%
symbol: str = 'SHFE.al2112'
period: str = 'Minute'

# %% [markdown]
# ### 加载数据

# %%
origin_data: pd.DataFrame = load_csv_as_dataframe(DATA_PATH.joinpath(f'{symbol}_{period}.csv'))
df_ohlc: pd.DataFrame = origin_data.loc['2021-10-15 13:30:00':'2021-10-19 00:59:00', ['open', 'high', 'low', 'close']]

df_ohlc.info()
print('-' * 100)
df_ohlc.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 795 entries, 2021-10-15 13:30:00 to 2021-10-19 00:59:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    795 non-null    float64
#  1   high    795 non-null    float64
#  2   low     795 non-null    float64
#  3   close   795 non-null    float64
# dtypes: float64(4)
# memory usage: 31.1 KB
# ----------------------------------------------------------------------------------------------------
#                         open     high      low    close
# datetime
# 2021-10-15 13:30:00  23900.0  23900.0  23840.0  23845.0
# 2021-10-15 13:31:00  23845.0  23895.0  23845.0  23895.0
# 2021-10-15 13:32:00  23895.0  23895.0  23855.0  23875.0
# 2021-10-15 13:33:00  23875.0  23895.0  23840.0  23845.0
# 2021-10-15 13:34:00  23845.0  23855.0  23830.0  23830.0

# %% [markdown]
# ### 定义计算结果

# %%
# df_chan 只是便于观察的中间结果。
df_chan: pd.DataFrame

# %% [markdown]
# ## 结果（100根K线）

# %% [markdown]
# ### 计算

# %%
count: int = 100
df_chan = chan_on_bar_dataframe(df_ohlc, count, debug=True)
# Out:
# 第    0 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 0, 高点 = 23900.0, 低点 = 23840.0
#     本K线（普通K线）：idx = 0, 高点 = 23900.0, 低点 = 23840.0
#
# 第    1 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 0, 高点 = 23900.0, 低点 = 23840.0
#     本K线（普通K线）：idx = 1, 高点 = 23895.0, 低点 = 23845.0
#
#     处理分型（缠论K线数量<2）：略过。
#
#     【本轮处理完毕】，费时 0:00:00.007006。
#
#     K线关系：包含
#     缠论K线数量：1，缠论高点：23900.0，缠论低点：23840.0，
#     前1缠论K线：（首根）0 ～ （末根）1，周期：2；
#     前2缠论K线：（首根）-1 ～ （末根）-1，周期：不存在；
#     前3缠论K线：（首根）-1 ～ （末根）-1。
#
# 第    2 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 1, 高点 = 23900.0, 低点 = 23840.0
#     本K线（普通K线）：idx = 2, 高点 = 23895.0, 低点 = 23855.0
#
#     处理分型（缠论K线数量<2）：略过。
#
#     【本轮处理完毕】，费时 0:00:00.010971。
#
#     K线关系：包含
#     缠论K线数量：1，缠论高点：23900.0，缠论低点：23840.0，
#     前1缠论K线：（首根）0 ～ （末根）2，周期：3；
#     前2缠论K线：（首根）-1 ～ （末根）-1，周期：不存在；
#     前3缠论K线：（首根）-1 ～ （末根）-1。
#
# 第    3 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 2, 高点 = 23900.0, 低点 = 23840.0
#     本K线（普通K线）：idx = 3, 高点 = 23895.0, 低点 = 23840.0
#
#     处理分型（缠论K线数量<2）：略过。
#
#     【本轮处理完毕】，费时 0:00:00.012965。
#
#     K线关系：包含
#     缠论K线数量：1，缠论高点：23900.0，缠论低点：23840.0，
#     前1缠论K线：（首根）0 ～ （末根）3，周期：4；
#     前2缠论K线：（首根）-1 ～ （末根）-1，周期：不存在；
#     前3缠论K线：（首根）-1 ～ （末根）-1。
#
# 第    4 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 3, 高点 = 23900.0, 低点 = 23840.0
#     本K线（普通K线）：idx = 4, 高点 = 23855.0, 低点 = 23830.0
#
#     处理分型（缠论K线数量=2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.016955。
#
#     K线关系：非
#     缠论K线数量：2，缠论高点：23855.0，缠论低点：23830.0，
#     前1缠论K线：（首根）4 ～ （末根）4，周期：1；
#     前2缠论K线：（首根）0 ～ （末根）3，周期：4；
#     前3缠论K线：（首根）-1 ～ （末根）-1。
#
# 第    5 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 4, 高点 = 23855.0, 低点 = 23830.0
#     本K线（普通K线）：idx = 5, 高点 = 23880.0, 低点 = 23830.0
#
#     处理分型（缠论K线数量=2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.020951。
#
#     K线关系：包含
#     缠论K线数量：2，缠论高点：23855.0，缠论低点：23830.0，
#     前1缠论K线：（首根）4 ～ （末根）5，周期：2；
#     前2缠论K线：（首根）0 ～ （末根）3，周期：4；
#     前3缠论K线：（首根）-1 ～ （末根）-1。
#
# 第    6 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 5, 高点 = 23855.0, 低点 = 23830.0
#     本K线（普通K线）：idx = 6, 高点 = 23900.0, 低点 = 23875.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.025931。
#
#     K线关系：非
#     缠论K线数量：3，缠论高点：23900.0，缠论低点：23875.0，
#     前1缠论K线：（首根）6 ～ （末根）6，周期：1；
#     前2缠论K线：（首根）4 ～ （末根）5，周期：2；
#     前3缠论K线：（首根）0 ～ （末根）3。
#
# 第    7 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 6, 高点 = 23900.0, 低点 = 23875.0
#     本K线（普通K线）：idx = 7, 高点 = 23915.0, 低点 = 23880.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.027928。
#
#     K线关系：非
#     缠论K线数量：4，缠论高点：23915.0，缠论低点：23880.0，
#     前1缠论K线：（首根）7 ～ （末根）7，周期：1；
#     前2缠论K线：（首根）6 ～ （末根）6，周期：1；
#     前3缠论K线：（首根）4 ～ （末根）5。
#
# 第    8 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 7, 高点 = 23915.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 8, 高点 = 23890.0, 低点 = 23845.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.031914。
#
#     K线关系：非
#     缠论K线数量：5，缠论高点：23890.0，缠论低点：23845.0，
#     前1缠论K线：（首根）8 ～ （末根）8，周期：1；
#     前2缠论K线：（首根）7 ～ （末根）7，周期：1；
#     前3缠论K线：（首根）6 ～ （末根）6。
#
# 第    9 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 8, 高点 = 23890.0, 低点 = 23845.0
#     本K线（普通K线）：idx = 9, 高点 = 23885.0, 低点 = 23860.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.034906。
#
#     K线关系：包含
#     缠论K线数量：5，缠论高点：23885.0，缠论低点：23845.0，
#     前1缠论K线：（首根）8 ～ （末根）9，周期：2；
#     前2缠论K线：（首根）7 ～ （末根）7，周期：1；
#     前3缠论K线：（首根）6 ～ （末根）6。
#
# 第   10 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 9, 高点 = 23885.0, 低点 = 23845.0
#     本K线（普通K线）：idx = 10, 高点 = 23920.0, 低点 = 23865.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.037900。
#
#     K线关系：非
#     缠论K线数量：6，缠论高点：23920.0，缠论低点：23865.0，
#     前1缠论K线：（首根）10 ～ （末根）10，周期：1；
#     前2缠论K线：（首根）8 ～ （末根）9，周期：2；
#     前3缠论K线：（首根）7 ～ （末根）7。
#
# 第   11 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 10, 高点 = 23920.0, 低点 = 23865.0
#     本K线（普通K线）：idx = 11, 高点 = 23955.0, 低点 = 23910.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.040890。
#
#     K线关系：非
#     缠论K线数量：7，缠论高点：23955.0，缠论低点：23910.0，
#     前1缠论K线：（首根）11 ～ （末根）11，周期：1；
#     前2缠论K线：（首根）10 ～ （末根）10，周期：1；
#     前3缠论K线：（首根）8 ～ （末根）9。
#
# 第   12 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 11, 高点 = 23955.0, 低点 = 23910.0
#     本K线（普通K线）：idx = 12, 高点 = 23985.0, 低点 = 23945.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.042887。
#
#     K线关系：非
#     缠论K线数量：8，缠论高点：23985.0，缠论低点：23945.0，
#     前1缠论K线：（首根）12 ～ （末根）12，周期：1；
#     前2缠论K线：（首根）11 ～ （末根）11，周期：1；
#     前3缠论K线：（首根）10 ～ （末根）10。
#
# 第   13 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 12, 高点 = 23985.0, 低点 = 23945.0
#     本K线（普通K线）：idx = 13, 高点 = 23980.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.046886。
#
#     K线关系：非
#     缠论K线数量：9，缠论高点：23980.0，缠论低点：23915.0，
#     前1缠论K线：（首根）13 ～ （末根）13，周期：1；
#     前2缠论K线：（首根）12 ～ （末根）12，周期：1；
#     前3缠论K线：（首根）11 ～ （末根）11。
#
# 第   14 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 13, 高点 = 23980.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 14, 高点 = 23945.0, 低点 = 23920.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.049866。
#
#     K线关系：包含
#     缠论K线数量：9，缠论高点：23945.0，缠论低点：23915.0，
#     前1缠论K线：（首根）13 ～ （末根）14，周期：2；
#     前2缠论K线：（首根）12 ～ （末根）12，周期：1；
#     前3缠论K线：（首根）11 ～ （末根）11。
#
# 第   15 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 14, 高点 = 23945.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 15, 高点 = 23935.0, 低点 = 23880.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.052858。
#
#     K线关系：非
#     缠论K线数量：10，缠论高点：23935.0，缠论低点：23880.0，
#     前1缠论K线：（首根）15 ～ （末根）15，周期：1；
#     前2缠论K线：（首根）13 ～ （末根）14，周期：2；
#     前3缠论K线：（首根）12 ～ （末根）12。
#
# 第   16 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 15, 高点 = 23935.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 16, 高点 = 23910.0, 低点 = 23880.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.055850。
#
#     K线关系：包含
#     缠论K线数量：10，缠论高点：23910.0，缠论低点：23880.0，
#     前1缠论K线：（首根）15 ～ （末根）16，周期：2；
#     前2缠论K线：（首根）13 ～ （末根）14，周期：2；
#     前3缠论K线：（首根）12 ～ （末根）12。
#
# 第   17 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 16, 高点 = 23910.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 17, 高点 = 23920.0, 低点 = 23895.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.057845。
#
#     K线关系：非
#     缠论K线数量：11，缠论高点：23920.0，缠论低点：23895.0，
#     前1缠论K线：（首根）17 ～ （末根）17，周期：1；
#     前2缠论K线：（首根）15 ～ （末根）16，周期：2；
#     前3缠论K线：（首根）13 ～ （末根）14。
#
# 第   18 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 17, 高点 = 23920.0, 低点 = 23895.0
#     本K线（普通K线）：idx = 18, 高点 = 23940.0, 低点 = 23910.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.060838。
#
#     K线关系：非
#     缠论K线数量：12，缠论高点：23940.0，缠论低点：23910.0，
#     前1缠论K线：（首根）18 ～ （末根）18，周期：1；
#     前2缠论K线：（首根）17 ～ （末根）17，周期：1；
#     前3缠论K线：（首根）15 ～ （末根）16。
#
# 第   19 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 18, 高点 = 23940.0, 低点 = 23910.0
#     本K线（普通K线）：idx = 19, 高点 = 23925.0, 低点 = 23885.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.065823。
#
#     K线关系：非
#     缠论K线数量：13，缠论高点：23925.0，缠论低点：23885.0，
#     前1缠论K线：（首根）19 ～ （末根）19，周期：1；
#     前2缠论K线：（首根）18 ～ （末根）18，周期：1；
#     前3缠论K线：（首根）17 ～ （末根）17。
#
# 第   20 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 19, 高点 = 23925.0, 低点 = 23885.0
#     本K线（普通K线）：idx = 20, 高点 = 23910.0, 低点 = 23880.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.067819。
#
#     K线关系：非
#     缠论K线数量：14，缠论高点：23910.0，缠论低点：23880.0，
#     前1缠论K线：（首根）20 ～ （末根）20，周期：1；
#     前2缠论K线：（首根）19 ～ （末根）19，周期：1；
#     前3缠论K线：（首根）18 ～ （末根）18。
#
# 第   21 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 20, 高点 = 23910.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 21, 高点 = 23915.0, 低点 = 23885.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.069814。
#
#     K线关系：非
#     缠论K线数量：15，缠论高点：23915.0，缠论低点：23885.0，
#     前1缠论K线：（首根）21 ～ （末根）21，周期：1；
#     前2缠论K线：（首根）20 ～ （末根）20，周期：1；
#     前3缠论K线：（首根）19 ～ （末根）19。
#
# 第   22 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 21, 高点 = 23915.0, 低点 = 23885.0
#     本K线（普通K线）：idx = 22, 高点 = 23905.0, 低点 = 23870.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.072805。
#
#     K线关系：非
#     缠论K线数量：16，缠论高点：23905.0，缠论低点：23870.0，
#     前1缠论K线：（首根）22 ～ （末根）22，周期：1；
#     前2缠论K线：（首根）21 ～ （末根）21，周期：1；
#     前3缠论K线：（首根）20 ～ （末根）20。
#
# 第   23 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 22, 高点 = 23905.0, 低点 = 23870.0
#     本K线（普通K线）：idx = 23, 高点 = 23895.0, 低点 = 23870.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.075797。
#
#     K线关系：包含
#     缠论K线数量：16，缠论高点：23895.0，缠论低点：23870.0，
#     前1缠论K线：（首根）22 ～ （末根）23，周期：2；
#     前2缠论K线：（首根）21 ～ （末根）21，周期：1；
#     前3缠论K线：（首根）20 ～ （末根）20。
#
# 第   24 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 23, 高点 = 23895.0, 低点 = 23870.0
#     本K线（普通K线）：idx = 24, 高点 = 23895.0, 低点 = 23870.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.078790。
#
#     K线关系：包含
#     缠论K线数量：16，缠论高点：23895.0，缠论低点：23870.0，
#     前1缠论K线：（首根）22 ～ （末根）24，周期：3；
#     前2缠论K线：（首根）21 ～ （末根）21，周期：1；
#     前3缠论K线：（首根）20 ～ （末根）20。
#
# 第   25 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 24, 高点 = 23895.0, 低点 = 23870.0
#     本K线（普通K线）：idx = 25, 高点 = 23895.0, 低点 = 23875.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.081782。
#
#     K线关系：包含
#     缠论K线数量：16，缠论高点：23895.0，缠论低点：23870.0，
#     前1缠论K线：（首根）22 ～ （末根）25，周期：4；
#     前2缠论K线：（首根）21 ～ （末根）21，周期：1；
#     前3缠论K线：（首根）20 ～ （末根）20。
#
# 第   26 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 25, 高点 = 23895.0, 低点 = 23870.0
#     本K线（普通K线）：idx = 26, 高点 = 23930.0, 低点 = 23895.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.084774。
#
#     K线关系：非
#     缠论K线数量：17，缠论高点：23930.0，缠论低点：23895.0，
#     前1缠论K线：（首根）26 ～ （末根）26，周期：1；
#     前2缠论K线：（首根）22 ～ （末根）25，周期：4；
#     前3缠论K线：（首根）21 ～ （末根）21。
#
# 第   27 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 26, 高点 = 23930.0, 低点 = 23895.0
#     本K线（普通K线）：idx = 27, 高点 = 23950.0, 低点 = 23920.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.086768。
#
#     K线关系：非
#     缠论K线数量：18，缠论高点：23950.0，缠论低点：23920.0，
#     前1缠论K线：（首根）27 ～ （末根）27，周期：1；
#     前2缠论K线：（首根）26 ～ （末根）26，周期：1；
#     前3缠论K线：（首根）22 ～ （末根）25。
#
# 第   28 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 27, 高点 = 23950.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 28, 高点 = 23945.0, 低点 = 23900.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.088762。
#
#     K线关系：非
#     缠论K线数量：19，缠论高点：23945.0，缠论低点：23900.0，
#     前1缠论K线：（首根）28 ～ （末根）28，周期：1；
#     前2缠论K线：（首根）27 ～ （末根）27，周期：1；
#     前3缠论K线：（首根）26 ～ （末根）26。
#
# 第   29 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 28, 高点 = 23945.0, 低点 = 23900.0
#     本K线（普通K线）：idx = 29, 高点 = 23930.0, 低点 = 23900.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.092752。
#
#     K线关系：包含
#     缠论K线数量：19，缠论高点：23930.0，缠论低点：23900.0，
#     前1缠论K线：（首根）28 ～ （末根）29，周期：2；
#     前2缠论K线：（首根）27 ～ （末根）27，周期：1；
#     前3缠论K线：（首根）26 ～ （末根）26。
#
# 第   30 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 29, 高点 = 23930.0, 低点 = 23900.0
#     本K线（普通K线）：idx = 30, 高点 = 23945.0, 低点 = 23920.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.097743。
#
#     K线关系：非
#     缠论K线数量：20，缠论高点：23945.0，缠论低点：23920.0，
#     前1缠论K线：（首根）30 ～ （末根）30，周期：1；
#     前2缠论K线：（首根）28 ～ （末根）29，周期：2；
#     前3缠论K线：（首根）27 ～ （末根）27。
#
# 第   31 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 30, 高点 = 23945.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 31, 高点 = 23935.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.099734。
#
#     K线关系：非
#     缠论K线数量：21，缠论高点：23935.0，缠论低点：23915.0，
#     前1缠论K线：（首根）31 ～ （末根）31，周期：1；
#     前2缠论K线：（首根）30 ～ （末根）30，周期：1；
#     前3缠论K线：（首根）28 ～ （末根）29。
#
# 第   32 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 31, 高点 = 23935.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 32, 高点 = 23940.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.102725。
#
#     K线关系：包含
#     缠论K线数量：21，缠论高点：23935.0，缠论低点：23915.0，
#     前1缠论K线：（首根）31 ～ （末根）32，周期：2；
#     前2缠论K线：（首根）30 ～ （末根）30，周期：1；
#     前3缠论K线：（首根）28 ～ （末根）29。
#
# 第   33 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 32, 高点 = 23935.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 33, 高点 = 23965.0, 低点 = 23940.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.106714。
#
#     K线关系：非
#     缠论K线数量：22，缠论高点：23965.0，缠论低点：23940.0，
#     前1缠论K线：（首根）33 ～ （末根）33，周期：1；
#     前2缠论K线：（首根）31 ～ （末根）32，周期：2；
#     前3缠论K线：（首根）30 ～ （末根）30。
#
# 第   34 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 33, 高点 = 23965.0, 低点 = 23940.0
#     本K线（普通K线）：idx = 34, 高点 = 23955.0, 低点 = 23925.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.113697。
#
#     K线关系：非
#     缠论K线数量：23，缠论高点：23955.0，缠论低点：23925.0，
#     前1缠论K线：（首根）34 ～ （末根）34，周期：1；
#     前2缠论K线：（首根）33 ～ （末根）33，周期：1；
#     前3缠论K线：（首根）31 ～ （末根）32。
#
# 第   35 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 34, 高点 = 23955.0, 低点 = 23925.0
#     本K线（普通K线）：idx = 35, 高点 = 23970.0, 低点 = 23940.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.117697。
#
#     K线关系：非
#     缠论K线数量：24，缠论高点：23970.0，缠论低点：23940.0，
#     前1缠论K线：（首根）35 ～ （末根）35，周期：1；
#     前2缠论K线：（首根）34 ～ （末根）34，周期：1；
#     前3缠论K线：（首根）33 ～ （末根）33。
#
# 第   36 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 35, 高点 = 23970.0, 低点 = 23940.0
#     本K线（普通K线）：idx = 36, 高点 = 23990.0, 低点 = 23960.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.122672。
#
#     K线关系：非
#     缠论K线数量：25，缠论高点：23990.0，缠论低点：23960.0，
#     前1缠论K线：（首根）36 ～ （末根）36，周期：1；
#     前2缠论K线：（首根）35 ～ （末根）35，周期：1；
#     前3缠论K线：（首根）34 ～ （末根）34。
#
# 第   37 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 36, 高点 = 23990.0, 低点 = 23960.0
#     本K线（普通K线）：idx = 37, 高点 = 24015.0, 低点 = 23980.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.124666。
#
#     K线关系：非
#     缠论K线数量：26，缠论高点：24015.0，缠论低点：23980.0，
#     前1缠论K线：（首根）37 ～ （末根）37，周期：1；
#     前2缠论K线：（首根）36 ～ （末根）36，周期：1；
#     前3缠论K线：（首根）35 ～ （末根）35。
#
# 第   38 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 37, 高点 = 24015.0, 低点 = 23980.0
#     本K线（普通K线）：idx = 38, 高点 = 24000.0, 低点 = 23970.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.127658。
#
#     K线关系：非
#     缠论K线数量：27，缠论高点：24000.0，缠论低点：23970.0，
#     前1缠论K线：（首根）38 ～ （末根）38，周期：1；
#     前2缠论K线：（首根）37 ～ （末根）37，周期：1；
#     前3缠论K线：（首根）36 ～ （末根）36。
#
# 第   39 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 38, 高点 = 24000.0, 低点 = 23970.0
#     本K线（普通K线）：idx = 39, 高点 = 23990.0, 低点 = 23970.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.129653。
#
#     K线关系：包含
#     缠论K线数量：27，缠论高点：23990.0，缠论低点：23970.0，
#     前1缠论K线：（首根）38 ～ （末根）39，周期：2；
#     前2缠论K线：（首根）37 ～ （末根）37，周期：1；
#     前3缠论K线：（首根）36 ～ （末根）36。
#
# 第   40 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 39, 高点 = 23990.0, 低点 = 23970.0
#     本K线（普通K线）：idx = 40, 高点 = 23985.0, 低点 = 23945.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.132644。
#
#     K线关系：非
#     缠论K线数量：28，缠论高点：23985.0，缠论低点：23945.0，
#     前1缠论K线：（首根）40 ～ （末根）40，周期：1；
#     前2缠论K线：（首根）38 ～ （末根）39，周期：2；
#     前3缠论K线：（首根）37 ～ （末根）37。
#
# 第   41 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 40, 高点 = 23985.0, 低点 = 23945.0
#     本K线（普通K线）：idx = 41, 高点 = 23960.0, 低点 = 23930.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.134639。
#
#     K线关系：非
#     缠论K线数量：29，缠论高点：23960.0，缠论低点：23930.0，
#     前1缠论K线：（首根）41 ～ （末根）41，周期：1；
#     前2缠论K线：（首根）40 ～ （末根）40，周期：1；
#     前3缠论K线：（首根）38 ～ （末根）39。
#
# 第   42 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 41, 高点 = 23960.0, 低点 = 23930.0
#     本K线（普通K线）：idx = 42, 高点 = 23945.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.136638。
#
#     K线关系：非
#     缠论K线数量：30，缠论高点：23945.0，缠论低点：23915.0，
#     前1缠论K线：（首根）42 ～ （末根）42，周期：1；
#     前2缠论K线：（首根）41 ～ （末根）41，周期：1；
#     前3缠论K线：（首根）40 ～ （末根）40。
#
# 第   43 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 42, 高点 = 23945.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 43, 高点 = 23955.0, 低点 = 23925.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.143616。
#
#     K线关系：非
#     缠论K线数量：31，缠论高点：23955.0，缠论低点：23925.0，
#     前1缠论K线：（首根）43 ～ （末根）43，周期：1；
#     前2缠论K线：（首根）42 ～ （末根）42，周期：1；
#     前3缠论K线：（首根）41 ～ （末根）41。
#
# 第   44 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 43, 高点 = 23955.0, 低点 = 23925.0
#     本K线（普通K线）：idx = 44, 高点 = 23955.0, 低点 = 23940.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.147605。
#
#     K线关系：包含
#     缠论K线数量：31，缠论高点：23955.0，缠论低点：23940.0，
#     前1缠论K线：（首根）43 ～ （末根）44，周期：2；
#     前2缠论K线：（首根）42 ～ （末根）42，周期：1；
#     前3缠论K线：（首根）41 ～ （末根）41。
#
# 第   45 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 44, 高点 = 23955.0, 低点 = 23940.0
#     本K线（普通K线）：idx = 45, 高点 = 23965.0, 低点 = 23950.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.150597。
#
#     K线关系：非
#     缠论K线数量：32，缠论高点：23965.0，缠论低点：23950.0，
#     前1缠论K线：（首根）45 ～ （末根）45，周期：1；
#     前2缠论K线：（首根）43 ～ （末根）44，周期：2；
#     前3缠论K线：（首根）42 ～ （末根）42。
#
# 第   46 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 45, 高点 = 23965.0, 低点 = 23950.0
#     本K线（普通K线）：idx = 46, 高点 = 23980.0, 低点 = 23955.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.153589。
#
#     K线关系：非
#     缠论K线数量：33，缠论高点：23980.0，缠论低点：23955.0，
#     前1缠论K线：（首根）46 ～ （末根）46，周期：1；
#     前2缠论K线：（首根）45 ～ （末根）45，周期：1；
#     前3缠论K线：（首根）43 ～ （末根）44。
#
# 第   47 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 46, 高点 = 23980.0, 低点 = 23955.0
#     本K线（普通K线）：idx = 47, 高点 = 23985.0, 低点 = 23955.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.156581。
#
#     K线关系：包含
#     缠论K线数量：33，缠论高点：23985.0，缠论低点：23955.0，
#     前1缠论K线：（首根）46 ～ （末根）47，周期：2；
#     前2缠论K线：（首根）45 ～ （末根）45，周期：1；
#     前3缠论K线：（首根）43 ～ （末根）44。
#
# 第   48 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 47, 高点 = 23985.0, 低点 = 23955.0
#     本K线（普通K线）：idx = 48, 高点 = 23970.0, 低点 = 23945.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.159573。
#
#     K线关系：非
#     缠论K线数量：34，缠论高点：23970.0，缠论低点：23945.0，
#     前1缠论K线：（首根）48 ～ （末根）48，周期：1；
#     前2缠论K线：（首根）46 ～ （末根）47，周期：2；
#     前3缠论K线：（首根）45 ～ （末根）45。
#
# 第   49 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 48, 高点 = 23970.0, 低点 = 23945.0
#     本K线（普通K线）：idx = 49, 高点 = 23960.0, 低点 = 23940.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.161568。
#
#     K线关系：非
#     缠论K线数量：35，缠论高点：23960.0，缠论低点：23940.0，
#     前1缠论K线：（首根）49 ～ （末根）49，周期：1；
#     前2缠论K线：（首根）48 ～ （末根）48，周期：1；
#     前3缠论K线：（首根）46 ～ （末根）47。
#
# 第   50 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 49, 高点 = 23960.0, 低点 = 23940.0
#     本K线（普通K线）：idx = 50, 高点 = 23950.0, 低点 = 23920.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.163562。
#
#     K线关系：非
#     缠论K线数量：36，缠论高点：23950.0，缠论低点：23920.0，
#     前1缠论K线：（首根）50 ～ （末根）50，周期：1；
#     前2缠论K线：（首根）49 ～ （末根）49，周期：1；
#     前3缠论K线：（首根）48 ～ （末根）48。
#
# 第   51 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 50, 高点 = 23950.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 51, 高点 = 23950.0, 低点 = 23935.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.165557。
#
#     K线关系：包含
#     缠论K线数量：36，缠论高点：23950.0，缠论低点：23920.0，
#     前1缠论K线：（首根）50 ～ （末根）51，周期：2；
#     前2缠论K线：（首根）49 ～ （末根）49，周期：1；
#     前3缠论K线：（首根）48 ～ （末根）48。
#
# 第   52 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 51, 高点 = 23950.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 52, 高点 = 23945.0, 低点 = 23930.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.168548。
#
#     K线关系：包含
#     缠论K线数量：36，缠论高点：23945.0，缠论低点：23920.0，
#     前1缠论K线：（首根）50 ～ （末根）52，周期：3；
#     前2缠论K线：（首根）49 ～ （末根）49，周期：1；
#     前3缠论K线：（首根）48 ～ （末根）48。
#
# 第   53 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 52, 高点 = 23945.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 53, 高点 = 23940.0, 低点 = 23880.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.170543。
#
#     K线关系：非
#     缠论K线数量：37，缠论高点：23940.0，缠论低点：23880.0，
#     前1缠论K线：（首根）53 ～ （末根）53，周期：1；
#     前2缠论K线：（首根）50 ～ （末根）52，周期：3；
#     前3缠论K线：（首根）49 ～ （末根）49。
#
# 第   54 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 53, 高点 = 23940.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 54, 高点 = 23930.0, 低点 = 23895.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.173535。
#
#     K线关系：包含
#     缠论K线数量：37，缠论高点：23930.0，缠论低点：23880.0，
#     前1缠论K线：（首根）53 ～ （末根）54，周期：2；
#     前2缠论K线：（首根）50 ～ （末根）52，周期：3；
#     前3缠论K线：（首根）49 ～ （末根）49。
#
# 第   55 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 54, 高点 = 23930.0, 低点 = 23880.0
#     本K线（普通K线）：idx = 55, 高点 = 23945.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.176528。
#
#     K线关系：非
#     缠论K线数量：38，缠论高点：23945.0，缠论低点：23915.0，
#     前1缠论K线：（首根）55 ～ （末根）55，周期：1；
#     前2缠论K线：（首根）53 ～ （末根）54，周期：2；
#     前3缠论K线：（首根）50 ～ （末根）52。
#
# 第   56 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 55, 高点 = 23945.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 56, 高点 = 23935.0, 低点 = 23905.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.179519。
#
#     K线关系：非
#     缠论K线数量：39，缠论高点：23935.0，缠论低点：23905.0，
#     前1缠论K线：（首根）56 ～ （末根）56，周期：1；
#     前2缠论K线：（首根）55 ～ （末根）55，周期：1；
#     前3缠论K线：（首根）53 ～ （末根）54。
#
# 第   57 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 56, 高点 = 23935.0, 低点 = 23905.0
#     本K线（普通K线）：idx = 57, 高点 = 23920.0, 低点 = 23885.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.181514。
#
#     K线关系：非
#     缠论K线数量：40，缠论高点：23920.0，缠论低点：23885.0，
#     前1缠论K线：（首根）57 ～ （末根）57，周期：1；
#     前2缠论K线：（首根）56 ～ （末根）56，周期：1；
#     前3缠论K线：（首根）55 ～ （末根）55。
#
# 第   58 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 57, 高点 = 23920.0, 低点 = 23885.0
#     本K线（普通K线）：idx = 58, 高点 = 23905.0, 低点 = 23885.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.184506。
#
#     K线关系：包含
#     缠论K线数量：40，缠论高点：23905.0，缠论低点：23885.0，
#     前1缠论K线：（首根）57 ～ （末根）58，周期：2；
#     前2缠论K线：（首根）56 ～ （末根）56，周期：1；
#     前3缠论K线：（首根）55 ～ （末根）55。
#
# 第   59 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 58, 高点 = 23905.0, 低点 = 23885.0
#     本K线（普通K线）：idx = 59, 高点 = 23910.0, 低点 = 23885.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.187498。
#
#     K线关系：包含
#     缠论K线数量：40，缠论高点：23905.0，缠论低点：23885.0，
#     前1缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前2缠论K线：（首根）56 ～ （末根）56，周期：1；
#     前3缠论K线：（首根）55 ～ （末根）55。
#
# 第   60 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 59, 高点 = 23905.0, 低点 = 23885.0
#     本K线（普通K线）：idx = 60, 高点 = 23935.0, 低点 = 23900.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.189492。
#
#     K线关系：非
#     缠论K线数量：41，缠论高点：23935.0，缠论低点：23900.0，
#     前1缠论K线：（首根）60 ～ （末根）60，周期：1；
#     前2缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前3缠论K线：（首根）56 ～ （末根）56。
#
# 第   61 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 60, 高点 = 23935.0, 低点 = 23900.0
#     本K线（普通K线）：idx = 61, 高点 = 23935.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.192485。
#
#     K线关系：包含
#     缠论K线数量：41，缠论高点：23935.0，缠论低点：23915.0，
#     前1缠论K线：（首根）60 ～ （末根）61，周期：2；
#     前2缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前3缠论K线：（首根）56 ～ （末根）56。
#
# 第   62 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 61, 高点 = 23935.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 62, 高点 = 23930.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.195477。
#
#     K线关系：包含
#     缠论K线数量：41，缠论高点：23935.0，缠论低点：23915.0，
#     前1缠论K线：（首根）60 ～ （末根）62，周期：3；
#     前2缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前3缠论K线：（首根）56 ～ （末根）56。
#
# 第   63 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 62, 高点 = 23935.0, 低点 = 23915.0
#     本K线（普通K线）：idx = 63, 高点 = 23935.0, 低点 = 23920.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.199466。
#
#     K线关系：包含
#     缠论K线数量：41，缠论高点：23935.0，缠论低点：23920.0，
#     前1缠论K线：（首根）60 ～ （末根）63，周期：4；
#     前2缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前3缠论K线：（首根）56 ～ （末根）56。
#
# 第   64 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 63, 高点 = 23935.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 64, 高点 = 23935.0, 低点 = 23915.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.202458。
#
#     K线关系：包含
#     缠论K线数量：41，缠论高点：23935.0，缠论低点：23920.0，
#     前1缠论K线：（首根）60 ～ （末根）64，周期：5；
#     前2缠论K线：（首根）57 ～ （末根）59，周期：3；
#     前3缠论K线：（首根）56 ～ （末根）56。
#
# 第   65 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 64, 高点 = 23935.0, 低点 = 23920.0
#     本K线（普通K线）：idx = 65, 高点 = 23945.0, 低点 = 23925.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.204453。
#
#     K线关系：非
#     缠论K线数量：42，缠论高点：23945.0，缠论低点：23925.0，
#     前1缠论K线：（首根）65 ～ （末根）65，周期：1；
#     前2缠论K线：（首根）60 ～ （末根）64，周期：5；
#     前3缠论K线：（首根）57 ～ （末根）59。
#
# 第   66 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 65, 高点 = 23945.0, 低点 = 23925.0
#     本K线（普通K线）：idx = 66, 高点 = 23980.0, 低点 = 23935.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.206448。
#
#     K线关系：非
#     缠论K线数量：43，缠论高点：23980.0，缠论低点：23935.0，
#     前1缠论K线：（首根）66 ～ （末根）66，周期：1；
#     前2缠论K线：（首根）65 ～ （末根）65，周期：1；
#     前3缠论K线：（首根）60 ～ （末根）64。
#
# 第   67 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 66, 高点 = 23980.0, 低点 = 23935.0
#     本K线（普通K线）：idx = 67, 高点 = 23980.0, 低点 = 23960.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.208442。
#
#     K线关系：包含
#     缠论K线数量：43，缠论高点：23980.0，缠论低点：23960.0，
#     前1缠论K线：（首根）66 ～ （末根）67，周期：2；
#     前2缠论K线：（首根）65 ～ （末根）65，周期：1；
#     前3缠论K线：（首根）60 ～ （末根）64。
#
# 第   68 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 67, 高点 = 23980.0, 低点 = 23960.0
#     本K线（普通K线）：idx = 68, 高点 = 23985.0, 低点 = 23965.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.210437。
#
#     K线关系：非
#     缠论K线数量：44，缠论高点：23985.0，缠论低点：23965.0，
#     前1缠论K线：（首根）68 ～ （末根）68，周期：1；
#     前2缠论K线：（首根）66 ～ （末根）67，周期：2；
#     前3缠论K线：（首根）65 ～ （末根）65。
#
# 第   69 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 68, 高点 = 23985.0, 低点 = 23965.0
#     本K线（普通K线）：idx = 69, 高点 = 24015.0, 低点 = 23960.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.213429。
#
#     K线关系：包含
#     缠论K线数量：44，缠论高点：24015.0，缠论低点：23965.0，
#     前1缠论K线：（首根）68 ～ （末根）69，周期：2；
#     前2缠论K线：（首根）66 ～ （末根）67，周期：2；
#     前3缠论K线：（首根）65 ～ （末根）65。
#
# 第   70 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 69, 高点 = 24015.0, 低点 = 23965.0
#     本K线（普通K线）：idx = 70, 高点 = 24085.0, 低点 = 24010.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.216435。
#
#     K线关系：非
#     缠论K线数量：45，缠论高点：24085.0，缠论低点：24010.0，
#     前1缠论K线：（首根）70 ～ （末根）70，周期：1；
#     前2缠论K线：（首根）68 ～ （末根）69，周期：2；
#     前3缠论K线：（首根）66 ～ （末根）67。
#
# 第   71 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 70, 高点 = 24085.0, 低点 = 24010.0
#     本K线（普通K线）：idx = 71, 高点 = 24110.0, 低点 = 24060.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.218426。
#
#     K线关系：非
#     缠论K线数量：46，缠论高点：24110.0，缠论低点：24060.0，
#     前1缠论K线：（首根）71 ～ （末根）71，周期：1；
#     前2缠论K线：（首根）70 ～ （末根）70，周期：1；
#     前3缠论K线：（首根）68 ～ （末根）69。
#
# 第   72 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 71, 高点 = 24110.0, 低点 = 24060.0
#     本K线（普通K线）：idx = 72, 高点 = 24095.0, 低点 = 24025.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.221408。
#
#     K线关系：非
#     缠论K线数量：47，缠论高点：24095.0，缠论低点：24025.0，
#     前1缠论K线：（首根）72 ～ （末根）72，周期：1；
#     前2缠论K线：（首根）71 ～ （末根）71，周期：1；
#     前3缠论K线：（首根）70 ～ （末根）70。
#
# 第   73 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 72, 高点 = 24095.0, 低点 = 24025.0
#     本K线（普通K线）：idx = 73, 高点 = 24075.0, 低点 = 24030.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.224400。
#
#     K线关系：包含
#     缠论K线数量：47，缠论高点：24075.0，缠论低点：24025.0，
#     前1缠论K线：（首根）72 ～ （末根）73，周期：2；
#     前2缠论K线：（首根）71 ～ （末根）71，周期：1；
#     前3缠论K线：（首根）70 ～ （末根）70。
#
# 第   74 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 73, 高点 = 24075.0, 低点 = 24025.0
#     本K线（普通K线）：idx = 74, 高点 = 24120.0, 低点 = 24060.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.229388。
#
#     K线关系：非
#     缠论K线数量：48，缠论高点：24120.0，缠论低点：24060.0，
#     前1缠论K线：（首根）74 ～ （末根）74，周期：1；
#     前2缠论K线：（首根）72 ～ （末根）73，周期：2；
#     前3缠论K线：（首根）71 ～ （末根）71。
#
# 第   75 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 74, 高点 = 24120.0, 低点 = 24060.0
#     本K线（普通K线）：idx = 75, 高点 = 24150.0, 低点 = 24095.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.232378。
#
#     K线关系：非
#     缠论K线数量：49，缠论高点：24150.0，缠论低点：24095.0，
#     前1缠论K线：（首根）75 ～ （末根）75，周期：1；
#     前2缠论K线：（首根）74 ～ （末根）74，周期：1；
#     前3缠论K线：（首根）72 ～ （末根）73。
#
# 第   76 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 75, 高点 = 24150.0, 低点 = 24095.0
#     本K线（普通K线）：idx = 76, 高点 = 24150.0, 低点 = 24095.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.234373。
#
#     K线关系：包含
#     缠论K线数量：49，缠论高点：24150.0，缠论低点：24095.0，
#     前1缠论K线：（首根）75 ～ （末根）76，周期：2；
#     前2缠论K线：（首根）74 ～ （末根）74，周期：1；
#     前3缠论K线：（首根）72 ～ （末根）73。
#
# 第   77 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 76, 高点 = 24150.0, 低点 = 24095.0
#     本K线（普通K线）：idx = 77, 高点 = 24300.0, 低点 = 24110.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.238362。
#
#     K线关系：非
#     缠论K线数量：50，缠论高点：24300.0，缠论低点：24110.0，
#     前1缠论K线：（首根）77 ～ （末根）77，周期：1；
#     前2缠论K线：（首根）75 ～ （末根）76，周期：2；
#     前3缠论K线：（首根）74 ～ （末根）74。
#
# 第   78 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 77, 高点 = 24300.0, 低点 = 24110.0
#     本K线（普通K线）：idx = 78, 高点 = 24315.0, 低点 = 24230.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.242352。
#
#     K线关系：非
#     缠论K线数量：51，缠论高点：24315.0，缠论低点：24230.0，
#     前1缠论K线：（首根）78 ～ （末根）78，周期：1；
#     前2缠论K线：（首根）77 ～ （末根）77，周期：1；
#     前3缠论K线：（首根）75 ～ （末根）76。
#
# 第   79 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 78, 高点 = 24315.0, 低点 = 24230.0
#     本K线（普通K线）：idx = 79, 高点 = 24315.0, 低点 = 24240.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.245344。
#
#     K线关系：包含
#     缠论K线数量：51，缠论高点：24315.0，缠论低点：24240.0，
#     前1缠论K线：（首根）78 ～ （末根）79，周期：2；
#     前2缠论K线：（首根）77 ～ （末根）77，周期：1；
#     前3缠论K线：（首根）75 ～ （末根）76。
#
# 第   80 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 79, 高点 = 24315.0, 低点 = 24240.0
#     本K线（普通K线）：idx = 80, 高点 = 24290.0, 低点 = 24205.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.249333。
#
#     K线关系：非
#     缠论K线数量：52，缠论高点：24290.0，缠论低点：24205.0，
#     前1缠论K线：（首根）80 ～ （末根）80，周期：1；
#     前2缠论K线：（首根）78 ～ （末根）79，周期：2；
#     前3缠论K线：（首根）77 ～ （末根）77。
#
# 第   81 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 80, 高点 = 24290.0, 低点 = 24205.0
#     本K线（普通K线）：idx = 81, 高点 = 24370.0, 低点 = 24275.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.252324。
#
#     K线关系：非
#     缠论K线数量：53，缠论高点：24370.0，缠论低点：24275.0，
#     前1缠论K线：（首根）81 ～ （末根）81，周期：1；
#     前2缠论K线：（首根）80 ～ （末根）80，周期：1；
#     前3缠论K线：（首根）78 ～ （末根）79。
#
# 第   82 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 81, 高点 = 24370.0, 低点 = 24275.0
#     本K线（普通K线）：idx = 82, 高点 = 24425.0, 低点 = 24345.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.255316。
#
#     K线关系：非
#     缠论K线数量：54，缠论高点：24425.0，缠论低点：24345.0，
#     前1缠论K线：（首根）82 ～ （末根）82，周期：1；
#     前2缠论K线：（首根）81 ～ （末根）81，周期：1；
#     前3缠论K线：（首根）80 ～ （末根）80。
#
# 第   83 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 82, 高点 = 24425.0, 低点 = 24345.0
#     本K线（普通K线）：idx = 83, 高点 = 24415.0, 低点 = 24355.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.257311。
#
#     K线关系：包含
#     缠论K线数量：54，缠论高点：24425.0，缠论低点：24355.0，
#     前1缠论K线：（首根）82 ～ （末根）83，周期：2；
#     前2缠论K线：（首根）81 ～ （末根）81，周期：1；
#     前3缠论K线：（首根）80 ～ （末根）80。
#
# 第   84 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 83, 高点 = 24425.0, 低点 = 24355.0
#     本K线（普通K线）：idx = 84, 高点 = 24420.0, 低点 = 24345.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.261301。
#
#     K线关系：非
#     缠论K线数量：55，缠论高点：24420.0，缠论低点：24345.0，
#     前1缠论K线：（首根）84 ～ （末根）84，周期：1；
#     前2缠论K线：（首根）82 ～ （末根）83，周期：2；
#     前3缠论K线：（首根）81 ～ （末根）81。
#
# 第   85 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 84, 高点 = 24420.0, 低点 = 24345.0
#     本K线（普通K线）：idx = 85, 高点 = 24405.0, 低点 = 24360.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.264293。
#
#     K线关系：包含
#     缠论K线数量：55，缠论高点：24405.0，缠论低点：24345.0，
#     前1缠论K线：（首根）84 ～ （末根）85，周期：2；
#     前2缠论K线：（首根）82 ～ （末根）83，周期：2；
#     前3缠论K线：（首根）81 ～ （末根）81。
#
# 第   86 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 85, 高点 = 24405.0, 低点 = 24345.0
#     本K线（普通K线）：idx = 86, 高点 = 24400.0, 低点 = 24370.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.267285。
#
#     K线关系：包含
#     缠论K线数量：55，缠论高点：24400.0，缠论低点：24345.0，
#     前1缠论K线：（首根）84 ～ （末根）86，周期：3；
#     前2缠论K线：（首根）82 ～ （末根）83，周期：2；
#     前3缠论K线：（首根）81 ～ （末根）81。
#
# 第   87 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 86, 高点 = 24400.0, 低点 = 24345.0
#     本K线（普通K线）：idx = 87, 高点 = 24445.0, 低点 = 24390.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.270277。
#
#     K线关系：非
#     缠论K线数量：56，缠论高点：24445.0，缠论低点：24390.0，
#     前1缠论K线：（首根）87 ～ （末根）87，周期：1；
#     前2缠论K线：（首根）84 ～ （末根）86，周期：3；
#     前3缠论K线：（首根）82 ～ （末根）83。
#
# 第   88 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 87, 高点 = 24445.0, 低点 = 24390.0
#     本K线（普通K线）：idx = 88, 高点 = 24450.0, 低点 = 24410.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.273268。
#
#     K线关系：非
#     缠论K线数量：57，缠论高点：24450.0，缠论低点：24410.0，
#     前1缠论K线：（首根）88 ～ （末根）88，周期：1；
#     前2缠论K线：（首根）87 ～ （末根）87，周期：1；
#     前3缠论K线：（首根）84 ～ （末根）86。
#
# 第   89 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 88, 高点 = 24450.0, 低点 = 24410.0
#     本K线（普通K线）：idx = 89, 高点 = 24430.0, 低点 = 24375.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.277273。
#
#     K线关系：非
#     缠论K线数量：58，缠论高点：24430.0，缠论低点：24375.0，
#     前1缠论K线：（首根）89 ～ （末根）89，周期：1；
#     前2缠论K线：（首根）88 ～ （末根）88，周期：1；
#     前3缠论K线：（首根）87 ～ （末根）87。
#
# 第   90 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 89, 高点 = 24430.0, 低点 = 24375.0
#     本K线（普通K线）：idx = 90, 高点 = 24680.0, 低点 = 24450.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.281247。
#
#     K线关系：非
#     缠论K线数量：59，缠论高点：24680.0，缠论低点：24450.0，
#     前1缠论K线：（首根）90 ～ （末根）90，周期：1；
#     前2缠论K线：（首根）89 ～ （末根）89，周期：1；
#     前3缠论K线：（首根）88 ～ （末根）88。
#
# 第   91 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 90, 高点 = 24680.0, 低点 = 24450.0
#     本K线（普通K线）：idx = 91, 高点 = 24635.0, 低点 = 24505.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.284239。
#
#     K线关系：包含
#     缠论K线数量：59，缠论高点：24680.0，缠论低点：24505.0，
#     前1缠论K线：（首根）90 ～ （末根）91，周期：2；
#     前2缠论K线：（首根）89 ～ （末根）89，周期：1；
#     前3缠论K线：（首根）88 ～ （末根）88。
#
# 第   92 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 91, 高点 = 24680.0, 低点 = 24505.0
#     本K线（普通K线）：idx = 92, 高点 = 24530.0, 低点 = 24440.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.288229。
#
#     K线关系：非
#     缠论K线数量：60，缠论高点：24530.0，缠论低点：24440.0，
#     前1缠论K线：（首根）92 ～ （末根）92，周期：1；
#     前2缠论K线：（首根）90 ～ （末根）91，周期：2；
#     前3缠论K线：（首根）89 ～ （末根）89。
#
# 第   93 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 92, 高点 = 24530.0, 低点 = 24440.0
#     本K线（普通K线）：idx = 93, 高点 = 24495.0, 低点 = 24390.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.291220。
#
#     K线关系：非
#     缠论K线数量：61，缠论高点：24495.0，缠论低点：24390.0，
#     前1缠论K线：（首根）93 ～ （末根）93，周期：1；
#     前2缠论K线：（首根）92 ～ （末根）92，周期：1；
#     前3缠论K线：（首根）90 ～ （末根）91。
#
# 第   94 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 93, 高点 = 24495.0, 低点 = 24390.0
#     本K线（普通K线）：idx = 94, 高点 = 24590.0, 低点 = 24490.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.294213。
#
#     K线关系：非
#     缠论K线数量：62，缠论高点：24590.0，缠论低点：24490.0，
#     前1缠论K线：（首根）94 ～ （末根）94，周期：1；
#     前2缠论K线：（首根）93 ～ （末根）93，周期：1；
#     前3缠论K线：（首根）92 ～ （末根）92。
#
# 第   95 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 94, 高点 = 24590.0, 低点 = 24490.0
#     本K线（普通K线）：idx = 95, 高点 = 24690.0, 低点 = 24565.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.296207。
#
#     K线关系：非
#     缠论K线数量：63，缠论高点：24690.0，缠论低点：24565.0，
#     前1缠论K线：（首根）95 ～ （末根）95，周期：1；
#     前2缠论K线：（首根）94 ～ （末根）94，周期：1；
#     前3缠论K线：（首根）93 ～ （末根）93。
#
# 第   96 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 95, 高点 = 24690.0, 低点 = 24565.0
#     本K线（普通K线）：idx = 96, 高点 = 24630.0, 低点 = 24580.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.298202。
#
#     K线关系：包含
#     缠论K线数量：63，缠论高点：24690.0，缠论低点：24580.0，
#     前1缠论K线：（首根）95 ～ （末根）96，周期：2；
#     前2缠论K线：（首根）94 ～ （末根）94，周期：1；
#     前3缠论K线：（首根）93 ～ （末根）93。
#
# 第   97 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 96, 高点 = 24690.0, 低点 = 24580.0
#     本K线（普通K线）：idx = 97, 高点 = 24620.0, 低点 = 24455.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【顶分型】。
#
#     【本轮处理完毕】，费时 0:00:00.301194。
#
#     K线关系：非
#     缠论K线数量：64，缠论高点：24620.0，缠论低点：24455.0，
#     前1缠论K线：（首根）97 ～ （末根）97，周期：1；
#     前2缠论K线：（首根）95 ～ （末根）96，周期：2；
#     前3缠论K线：（首根）94 ～ （末根）94。
#
# 第   98 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 97, 高点 = 24620.0, 低点 = 24455.0
#     本K线（普通K线）：idx = 98, 高点 = 24460.0, 低点 = 24340.0
#
#     处理分型（缠论K线数量>2）：
#     【本轮处理完毕】，费时 0:00:00.304189。
#
#     K线关系：非
#     缠论K线数量：65，缠论高点：24460.0，缠论低点：24340.0，
#     前1缠论K线：（首根）98 ～ （末根）98，周期：1；
#     前2缠论K线：（首根）97 ～ （末根）97，周期：1；
#     前3缠论K线：（首根）95 ～ （末根）96。
#
# 第   99 /  100 （普通K线）轮：
#     前K线（缠论K线）：idx = 98, 高点 = 24460.0, 低点 = 24340.0
#     本K线（普通K线）：idx = 99, 高点 = 24510.0, 低点 = 24435.0
#
#     处理分型（缠论K线数量>2）：
#         前2缠论K线视作【底分型】。
#
#     【本轮处理完毕】，费时 0:00:00.306180。
#
#     K线关系：非
#     缠论K线数量：66，缠论高点：24510.0，缠论低点：24435.0，
#     前1缠论K线：（首根）99 ～ （末根）99，周期：1；
#     前2缠论K线：（首根）98 ～ （末根）98，周期：1；
#     前3缠论K线：（首根）97 ～ （末根）97。
#
#
# 计算完成！
# 总计花费： 0:00:00.307178

# %% [markdown]
# ### 数据

# %%
pd.set_option('display.max_rows', count)
df_chan.head(count)
# Out:
#       包含？  缠论K线数量  缠论周期     缠论高点     缠论低点 分型类型 分型性质
# 0   False       1     1  23900.0  23840.0    -    -
# 1    True       1     2  23900.0  23840.0    -    -
# 2    True       1     3  23900.0  23840.0    -    -
# 3    True       1     4  23900.0  23840.0    顶   临时
# 4   False       2     1  23855.0  23830.0    -    -
# 5    True       2     2  23855.0  23830.0    底   临时
# 6   False       3     1  23900.0  23875.0    -    -
# 7   False       4     1  23915.0  23880.0    顶   临时
# 8   False       5     1  23890.0  23845.0    -    -
# 9    True       5     2  23885.0  23845.0    底   临时
# 10  False       6     1  23920.0  23865.0    -    -
# 11  False       7     1  23955.0  23910.0    -    -
# 12  False       8     1  23985.0  23945.0    顶   临时
# 13  False       9     1  23980.0  23915.0    -    -
# 14   True       9     2  23945.0  23915.0    -    -
# 15  False      10     1  23935.0  23880.0    -    -
# 16   True      10     2  23910.0  23880.0    底   临时
# 17  False      11     1  23920.0  23895.0    -    -
# 18  False      12     1  23940.0  23910.0    顶   临时
# 19  False      13     1  23925.0  23885.0    -    -
# 20  False      14     1  23910.0  23880.0    底   临时
# 21  False      15     1  23915.0  23885.0    顶   临时
# 22  False      16     1  23905.0  23870.0    -    -
# 23   True      16     2  23895.0  23870.0    -    -
# 24   True      16     3  23895.0  23870.0    -    -
# 25   True      16     4  23895.0  23870.0    底   临时
# 26  False      17     1  23930.0  23895.0    -    -
# 27  False      18     1  23950.0  23920.0    顶   临时
# 28  False      19     1  23945.0  23900.0    -    -
# 29   True      19     2  23930.0  23900.0    底   临时
# 30  False      20     1  23945.0  23920.0    顶   临时
# 31  False      21     1  23935.0  23915.0    -    -
# 32   True      21     2  23935.0  23915.0    底   临时
# 33  False      22     1  23965.0  23940.0    顶   临时
# 34  False      23     1  23955.0  23925.0    底   临时
# 35  False      24     1  23970.0  23940.0    -    -
# 36  False      25     1  23990.0  23960.0    -    -
# 37  False      26     1  24015.0  23980.0    顶   临时
# 38  False      27     1  24000.0  23970.0    -    -
# 39   True      27     2  23990.0  23970.0    -    -
# 40  False      28     1  23985.0  23945.0    -    -
# 41  False      29     1  23960.0  23930.0    -    -
# 42  False      30     1  23945.0  23915.0    底   临时
# 43  False      31     1  23955.0  23925.0    -    -
# 44   True      31     2  23955.0  23940.0    -    -
# 45  False      32     1  23965.0  23950.0    -    -
# 46  False      33     1  23980.0  23955.0    -    -
# 47   True      33     2  23985.0  23955.0    顶   临时
# 48  False      34     1  23970.0  23945.0    -    -
# 49  False      35     1  23960.0  23940.0    -    -
# 50  False      36     1  23950.0  23920.0    -    -
# 51   True      36     2  23950.0  23920.0    -    -
# 52   True      36     3  23945.0  23920.0    -    -
# 53  False      37     1  23940.0  23880.0    -    -
# 54   True      37     2  23930.0  23880.0    底   临时
# 55  False      38     1  23945.0  23915.0    顶   临时
# 56  False      39     1  23935.0  23905.0    -    -
# 57  False      40     1  23920.0  23885.0    -    -
# 58   True      40     2  23905.0  23885.0    -    -
# 59   True      40     3  23905.0  23885.0    底   临时
# 60  False      41     1  23935.0  23900.0    -    -
# 61   True      41     2  23935.0  23915.0    -    -
# 62   True      41     3  23935.0  23915.0    -    -
# 63   True      41     4  23935.0  23920.0    -    -
# 64   True      41     5  23935.0  23920.0    -    -
# 65  False      42     1  23945.0  23925.0    -    -
# 66  False      43     1  23980.0  23935.0    -    -
# 67   True      43     2  23980.0  23960.0    -    -
# 68  False      44     1  23985.0  23965.0    -    -
# 69   True      44     2  24015.0  23965.0    -    -
# 70  False      45     1  24085.0  24010.0    -    -
# 71  False      46     1  24110.0  24060.0    顶   临时
# 72  False      47     1  24095.0  24025.0    -    -
# 73   True      47     2  24075.0  24025.0    底   临时
# 74  False      48     1  24120.0  24060.0    -    -
# 75  False      49     1  24150.0  24095.0    -    -
# 76   True      49     2  24150.0  24095.0    -    -
# 77  False      50     1  24300.0  24110.0    -    -
# 78  False      51     1  24315.0  24230.0    -    -
# 79   True      51     2  24315.0  24240.0    顶   临时
# 80  False      52     1  24290.0  24205.0    底   临时
# 81  False      53     1  24370.0  24275.0    -    -
# 82  False      54     1  24425.0  24345.0    -    -
# 83   True      54     2  24425.0  24355.0    顶   临时
# 84  False      55     1  24420.0  24345.0    -    -
# 85   True      55     2  24405.0  24345.0    -    -
# 86   True      55     3  24400.0  24345.0    底   临时
# 87  False      56     1  24445.0  24390.0    -    -
# 88  False      57     1  24450.0  24410.0    顶   临时
# 89  False      58     1  24430.0  24375.0    底   临时
# 90  False      59     1  24680.0  24450.0    -    -
# 91   True      59     2  24680.0  24505.0    顶   临时
# 92  False      60     1  24530.0  24440.0    -    -
# 93  False      61     1  24495.0  24390.0    底   临时
# 94  False      62     1  24590.0  24490.0    -    -
# 95  False      63     1  24690.0  24565.0    -    -
# 96   True      63     2  24690.0  24580.0    顶   临时
# 97  False      64     1  24620.0  24455.0    -    -
# 98  False      65     1  24460.0  24340.0    底   临时
# 99  False      66     1  24510.0  24435.0    -    -

# %% [markdown]
# ### 绘图

# %%
plot_chan_dataframe(df_ohlc, df_chan, count)
# Out:
# Done.

# %% [markdown]
# ## 结果（500根K线）

# %%
# count: int = 500
# df_chan = chan_on_bar_dataframe(df_ohlc, count)

# plot_chan_dataframe(df_ohlc, df_chan, count)

# %%
# pd.set_option('display.max_rows', count)
# df_chan.head(count)
